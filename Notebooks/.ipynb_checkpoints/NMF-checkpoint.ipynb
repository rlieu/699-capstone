# %%
#Import necessary libraries
import numpy as np
import pandas as pd
import scipy.sparse as sp
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
from gensim.models.coherencemodel import CoherenceModel
from gensim.corpora.dictionary import Dictionary
from gensim import corpora, models

# %%
df = pd.read_csv('preprocessed_df.csv')

# %%
df.dropna(inplace=True)

# %%
vec = TfidfVectorizer(max_df=0.95, min_df=2, max_features=1000)
tfidf = vec.fit_transform(df['preprocessed_text'])

# %%
feature_names = vec.get_feature_names_out()

# %%
#Set random state
random_state = 696

# %%
#get the feature ready for the coherence model

df['preprocessed_text'] = df['preprocessed_text'].apply(lambda x: x.split())
texts = df['preprocessed_text'].tolist()
dictionary = corpora.Dictionary(texts)

# %%
num_top_words = 100
coherence_scores = []
best_avg_coherence = 0
best_model = None
best_W = None
best_H = None

for num_topics in range(2,11):
    nmf = NMF(n_components = num_topics, 
                  max_iter = 200, init = 'nndsvd', random_state = random_state)
    W = nmf.fit_transform(tfidf)
    H = nmf.components_
    
    topics = []
    for topic_idx, topic in enumerate(H):
        top_features_ind = topic.argsort()[-num_top_words:][::-1]
        top_features = [feature_names[i] for i in top_features_ind]
        topics.append(top_features)
        
    coherence_model = CoherenceModel(topics=topics, texts=texts, dictionary=dictionary, coherence='c_v')
    avg_c = coherence_model.get_coherence()
    coherence_scores.append(avg_c)
    
    if avg_c > best_avg_coherence:
        best_avg_coherence = avg_c
        best_model = nmf
        best_W = W
        best_H = H
# Out:
# /home/qianfu/.local/lib/python3.10/site-packages/sklearn/decomposition/_nmf.py:1770: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(
# /home/qianfu/.local/lib/python3.10/site-packages/sklearn/decomposition/_nmf.py:1770: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(

# %%
best_model
# Out:
# NMF(init='nndsvd', n_components=10, random_state=696)

# %%
with open('out/best_model.pkl', 'wb') as f:
    pickle.dump(best_model, f)

# %%
coherence_scores
# Out:
# [0.3470058271772469,
#  0.36834263644077286,
#  0.35041435750632727,
#  0.3674657430424791,
#  0.3958608813253665,
#  0.3988099377494648,
#  0.4065147783386126,
#  0.4058151736220475,
#  0.42632352173416327]

# %%
plt.plot(np.arange(2,11), coherence_scores)
plt.xlabel('Number of Topics')
plt.ylabel('Average Coherence Score')
plt.title('Coherence Scores of NMF Trained With Different Number of Topics')
plt.scatter(best_model.n_components, coherence_scores[best_model.n_components -2], c='red', marker='o', s=100)

# %%
#print out the top 50 words for each topic

num_top_words = 50

for topic_idx, topic in enumerate(best_H):
    print(f"Topic {topic_idx + 1}:")
    top_features_ind = topic.argsort()[-num_top_words:][::-1]  
    top_features = [feature_names[i] for i in top_features_ind]
    top_features_str = ", ".join(top_features)
    print(top_features_str)
# Out:
# Topic 1:
# get, go, work, time, day, sleep, back, start, job, week, every, try, need, hour, last, thing, night, well, keep, month, bad, hard, home, really, year, wake, long, even, one, make, come, use, do, today, could, bed, ill, still, first, put, able, much, class, end, help, minute, leave, school, next, new
# Topic 2:
# ocd, compulsion, obsession, bad, fear, anxiety, theme, diagnose, help, therapist, contamination, symptom, erp, harm, thing, therapy, disorder, suffer, make, check, hand, event, think, real, mental, deal, also, obsess, reassurance, wash, worry, treatment, pocd, false, touch, illness, since, ritual, wonder, past, go, certain, please, something, hi, might, health, cause, develop, type
# Topic 3:
# adhd, diagnose, help, diagnosis, symptom, medication, get, doctor, struggle, psychiatrist, year, school, test, anxiety, also, lot, issue, med, appointment, depression, focus, find, need, recently, work, well, thank, disorder, really, read, therapist, mental, learn, since, wonder, therapy, health, adult, treatment, task, know, advice, life, study, research, prescribe, try, tell, might, parent
# Topic 4:
# feel, like, feeling, make, bad, really, way, sometimes, everything, body, thing, time, something, emotion, idk, guilty, always, normal, weird, sad, alone, nothing, well, even, happy, brain, depression, real, anxious, hard, right, much, numb, constantly, ever, wrong, anxiety, hate, depressed, sense, shit, person, head, almost, self, seem, empty, anything, cry, moment
# Topic 5:
# people, say, think, thing, would, make, like, talk, something, tell, not, someone, one, ask, see, know, really, look, understand, also, try, time, person, way, find, always, even, could, lot, social, read, mean, friend, use, post, asperger, come, question, autistic, many, hear, conversation, seem, remember, sometimes, actually, other, never, word, sure
# Topic 6:
# not, can, know, want, anymore, even, anything, stop, think, will, tell, fucking, need, really, wanna, go, help, get, keep, everything, cry, hate, right, scared, take, bad, tired, care, hurt, happen, eat, shit, without, fuck, much, remember, nothing, could, literally, try, see, wrong, please, thing, mind, sorry, do, matter, understand, let
# Topic 7:
# thought, intrusive, think, get, head, mind, compulsion, anxiety, bad, brain, sexual, start, happen, come, fear, sometimes, scared, obsessive, stop, harm, really, would, like, something, person, cause, horrible, try, true, real, go, ill, feeling, scare, anxious, obsession, pop, pocd, panic, worry, actually, keep, ruminate, suicidal, help, image, urge, normal, control, imagine
# Topic 8:
# life, want, friend, year, live, love, never, family, go, hate, good, one, die, happy, parent, relationship, alone, leave, depression, care, old, school, everything, ever, would, lose, much, end, everyone, mom, hurt, kill, fucking, nothing, still, since, always, wish, away, dad, well, shit, fuck, give, pain, see, tell, make, back, abuse
# Topic 9:
# anyone, else, experience, ptsd, happen, trauma, wonder, trigger, similar, know, relate, thank, something, deal, advice, flashback, find, symptom, attack, help, panic, really, recently, memory, hear, notice, nightmare, curious, hi, issue, therapy, anything, struggle, share, tip, someone, traumatic, event, abuse, cope, therapist, seem, feeling, anxiety, cause, often, sometimes, appreciate, year, way
# Topic 10:
# take, mg, med, adderall, medication, day, effect, vyvanse, dose, start, week, prescribe, side, doctor, xr, concerta, first, hour, month, experience, ritalin, pill, work, switch, notice, morning, increase, stimulant, try, ago, psychiatrist, two, change, anxiety, eat, focus, drug, long, high, last, much, would, today, low, also, prescription, not, bit, since, maybe

# %%
#get the dominant topic for each post
dominant_topics = np.argmax(best_W, axis=1)
#count the posts for each topic
posts_per_topic = np.bincount(dominant_topics, minlength=best_model.n_components)

# visual the distribution
plt.figure(figsize=(10, 6))
topics = range(1, best_model.n_components + 1)
plt.bar(topics, posts_per_topic, color='skyblue')
plt.xlabel('Topic')
plt.ylabel('Number of Articles')
plt.title('Distribution of Articles Across Topics')
plt.xticks(topics) 
plt.show()
